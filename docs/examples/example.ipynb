# %%
import math

# %% [markdown]
# ## Example Usage
#
# Here to demonstrate teh usage of ```example_function```

# %%
def example_function():
    """Example Function
    
    This is a detailed description.
    
    Parameters
    ----------
    name : type
        Parameter description
        
    Returns
    -------
    name (optional): type
        Return description
    
    Examples
    --------
    >>> example_function()
    """
    
    print('this is an example function')

# %%
example_function()
# Out:
# this is an example function
